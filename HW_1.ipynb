# %% [markdown]
# <a href="https://colab.research.google.com/github/brando710/brando710.github.io/blob/main/HW_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input('What is your name?')
print ('Hello ' + name + '!')

number1 = int(input('Give me a number'))
number2 = int(input('Give me another number'))
print ('sum = ' + str(number1 + number2))
print ('difference = ' + str(number1 - number2))
print ('product = ' + str(number1 * number2))
print ('quotient = ' + str(number1 / number2))


temperature = int(input('What is the temperature in celsius?'))
print ('The temperature in fahrenheit is ' + str(temperature * 1.8 + 32))
# Out:
# What is your name?liam
# Hello liam!
# Give me a number2
# Give me another number2
# sum = 4
# difference = 0
# product = 4
# quotient = 1.0
# What is the temperature in celsius?50
# The temperature in fahrenheit is 122.0
